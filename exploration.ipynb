# %% [markdown]
# # Data Exploration

# %% [markdown]
# Here we simply explore the data to see what we are working with.

# %%
import pandas as pd

df = pd.read_csv('data/Books_rating.csv')
df.head()
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4  0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
#
#                           profileName review/helpfulness  review/score  \
# 0               Jim of Oz "jim-of-oz"                7/7           4.0
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
# 4     D. H. Richards "ninthwavestore"                3/3           4.0
#
#    review/time                                   review/summary  \
# ...

# %% [markdown]
# First, let's check the distribution of scores in the dataset.

# %%
import matplotlib.pyplot as plt

plt.hist(df['review/score'])
plt.title('Distribution of Score')
plt.xlabel('Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# It appears most ratings are skewed towards a score of five. This could be due to the fact that most people only review products they like. This may cause a problem when trianing our model such that it will skew towards predicting higher scores. It's also worth noting that there are no scores in what we would expect the mean to be.

# %% [markdown]
# Let's see if we can find correlation between scores to other attributes of the text.

# %%
df['review/word_count'] = df['review/text'].str.split().str.len()
df.head()

plt.scatter(df['review/word_count'], df['review/score'])
plt.title('Review Length vs Score')
plt.xlabel('Review Length')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# It would seem there is a pretty even distribution of review length for various scores. However, we can see that as reviews get better there is generally a higher word count. This could be due to the fact that people who like a product are more likely to write more about it.
